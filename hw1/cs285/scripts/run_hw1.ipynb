# %% [markdown]
# ##Setup
#
# You will need to make a copy of this notebook in your Google Drive before you can edit the homework files. You can do so with **File &rarr; Save a copy in Drive**.

# %%
#@title update mujoco paths

import os

home = os.path.expanduser('~')
ex_path = '/Documents/Python/BerkeleyDRL_fall2021/hw1'
MJC_PATH = home + '/.mujoco'
if home[:6] == '/Users':
    os.environ['LIBRARY_PATH'] += '/usr/local/lib'
    os.environ['LIBRARY_PATH'] += ':{}/mujoco200/bin'.format(MJC_PATH)   
else:
    os.environ['LD_LIBRARY_PATH'] = '/usr/local/nvidia/lib64'
    os.environ['LD_LIBRARY_PATH'] += ':{}/mujoco200/bin'.format(MJC_PATH)

os.environ['MUJOCO_PY_MUJOCO_PATH'] = '{}/mujoco200'.format(MJC_PATH)
os.environ['MUJOCO_PY_MJKEY_PATH'] = '{}/mjkey.txt'.format(MJC_PATH)

## installation on colab does not find *.so files
## in LD_LIBRARY_PATH, copy over manually instead
## !cp $MJC_PATH/mujoco200/bin/*.so /usr/lib/x86_64-linux-gnu/

# %% [markdown]
# Copy over `mjkey.txt` into `~/.mujoco` before this step

# %%
#@title clone and install mujoco-py

## cythonize at the first import
import mujoco_py
# Out:
# objc[78759]: Class GLFWApplicationDelegate is implemented in both /Users/ikasou/Downloads/mujoco200/bin/libglfw.3.dylib (0x130bb8778) and /Users/ikasou/Library/Python/3.8/lib/python/site-packages/glfw/libglfw.3.dylib (0x130d276e8). One of the two will be used. Which one is undefined.
# objc[78759]: Class GLFWWindowDelegate is implemented in both /Users/ikasou/Downloads/mujoco200/bin/libglfw.3.dylib (0x130bb8700) and /Users/ikasou/Library/Python/3.8/lib/python/site-packages/glfw/libglfw.3.dylib (0x130d27710). One of the two will be used. Which one is undefined.
# objc[78759]: Class GLFWContentView is implemented in both /Users/ikasou/Downloads/mujoco200/bin/libglfw.3.dylib (0x130bb87a0) and /Users/ikasou/Library/Python/3.8/lib/python/site-packages/glfw/libglfw.3.dylib (0x130d27760). One of the two will be used. Which one is undefined.
# objc[78759]: Class GLFWWindow is implemented in both /Users/ikasou/Downloads/mujoco200/bin/libglfw.3.dylib (0x130bb8818) and /Users/ikasou/Library/Python/3.8/lib/python/site-packages/glfw/libglfw.3.dylib (0x130d277d8). One of the two will be used. Which one is undefined.

# %%
#@title clone homework repo
'''
# %cd $SYM_PATH
# !git clone https://github.com/berkeleydeeprlcourse/homework_fall2021.git
# %cd homework_fall2021/hw1
# %pip install -r requirements_colab.txt
# %pip install -e . ''';

# %%
#@title set up virtual display

from pyvirtualdisplay import Display

display = Display(visible=0, size=(1400, 900))
display.start();

# %%
#@title test virtual display

#@markdown If you see a video of a four-legged ant fumbling about, setup is complete!

import gym
from cs285.infrastructure.colab_utils import (
    wrap_env,
    show_video
) 

env = wrap_env(gym.make("Ant-v2"))

observation = env.reset()
for i in range(100):
    env.render(mode='rgb_array')
    obs, rew, term, _ = env.step(env.action_space.sample() ) 
    if term:
      break;
            
env.close()
print('Loading video...')
show_video()
# Out:
# Creating offscreen glfw
# Loading video...
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## Editing Code
#
# To edit code, click the folder icon on the left menu. Navigate to the corresponding file (`cs285_f2021/...`). Double click a file to open an editor. There is a timeout of about ~12 hours with Colab while it is active (and less if you close your browser window). We sync your edits to Google Drive so that you won't lose your work in the event of an instance timeout, but you will need to re-mount your Google Drive and re-install packages with every new instance.

# %% [markdown]
# ## Run Behavior Cloning (Problem 1)

# %%
#@title imports

import os
import time
import numpy as np

from cs285.infrastructure.rl_trainer import RL_Trainer
from cs285.agents.bc_agent import BCAgent
from cs285.policies.loaded_gaussian_policy import LoadedGaussianPolicy

# %load_ext autoreload
# %autoreload 2

# %%
#@title runtime arguments

class Args:

  def __getitem__(self, key):
    return getattr(self, key)

  def __setitem__(self, key, val):
    setattr(self, key, val)

  #@markdown expert data
  expert_policy_file = home + ex_path + '/cs285/policies/experts/Ant.pkl' #@param
  expert_data = home + ex_path + '/cs285/expert_data/expert_data_Ant-v2.pkl' #@param
  env_name = 'Ant-v2' #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
  exp_name = 'test_bc_ant' #@param
  do_dagger = False #@param {type: "boolean"}
  ep_len = 1000 #@param {type: "integer"}
  save_params = False #@param {type: "boolean"}

  num_agent_train_steps_per_iter = 1000 #@param {type: "integer"})
  n_iter = 1 #@param {type: "integer"})

  #@markdown batches & buffers
  batch_size = 1000 #@param {type: "integer"})
  eval_batch_size = 1000 #@param {type: "integer"}
  train_batch_size = 100 #@param {type: "integer"}
  max_replay_buffer_size = 1000000 #@param {type: "integer"}

  #@markdown network
  n_layers = 2 #@param {type: "integer"}
  size = 64 #@param {type: "integer"}
  learning_rate = 5e-3 #@param {type: "number"}

  #@markdown logging
  video_log_freq = 5 #@param {type: "integer"}
  scalar_log_freq = 1 #@param {type: "integer"}

  #@markdown gpu & run-time settings
  no_gpu = False #@param {type: "boolean"}
  which_gpu = 0 #@param {type: "integer"}
  seed = 1 #@param {type: "integer"}

args = Args()

# %%
#@title define `BC_Trainer`
class BC_Trainer(object):

    def __init__(self, params):
        #######################
        ## AGENT PARAMS
        #######################

        agent_params = {
            'n_layers': params['n_layers'],
            'size': params['size'],
            'learning_rate': params['learning_rate'],
            'max_replay_buffer_size': params['max_replay_buffer_size'],
            }

        self.params = params
        self.params['agent_class'] = BCAgent ## TODO: look in here and implement this
        self.params['agent_params'] = agent_params

        ################
        ## RL TRAINER
        ################

        self.rl_trainer = RL_Trainer(self.params) ## TODO: look in here and implement this

        #######################
        ## LOAD EXPERT POLICY
        #######################

        print('Loading expert policy from...', self.params['expert_policy_file'])
        self.loaded_expert_policy = LoadedGaussianPolicy(self.params['expert_policy_file'])
        print('Done restoring expert policy...')

    def run_training_loop(self):

        self.rl_trainer.run_training_loop(
            n_iter=self.params['n_iter'],
            initial_expertdata=self.params['expert_data'],
            collect_policy=self.rl_trainer.agent.actor,
            eval_policy=self.rl_trainer.agent.actor,
            relabel_with_expert=self.params['do_dagger'],
            expert_policy=self.loaded_expert_policy,
        )

# %%
#@title create directory for logging

if args.do_dagger:
    logdir_prefix = 'q2_'  # The autograder uses the prefix `q2_`
    assert args.n_iter>1, ('DAgger needs more than 1 iteration (n_iter>1) of training, to iteratively query the expert and train (after 1st warmstarting from behavior cloning).')
else:
    logdir_prefix = 'q1_'  # The autograder uses the prefix `q1_`
    assert args.n_iter==1, ('Vanilla behavior cloning collects expert data just once (n_iter=1)')

data_path = home + ex_path + '/hw1/data'
if not (os.path.exists(data_path)):
    os.makedirs(data_path)
logdir = logdir_prefix + args.exp_name + '_' + args.env_name + \
         '_' + time.strftime("%d-%m-%Y_%H-%M-%S")
logdir = os.path.join(data_path, logdir)
args['logdir'] = logdir
if not(os.path.exists(logdir)):
    os.makedirs(logdir)

# %%
## run training
print(args.logdir)
trainer = BC_Trainer(args)
trainer.run_training_loop()
# Out:
# /Users/ikasou/Documents/Python/BerkeleyDRL_fall2021/hw1/hw1/data/q1_test_bc_ant_Ant-v2_17-11-2021_18-59-33
# ########################
# logging outputs to  /Users/ikasou/Documents/Python/BerkeleyDRL_fall2021/hw1/hw1/data/q1_test_bc_ant_Ant-v2_17-11-2021_18-59-33
# ########################
# GPU not detected. Defaulting to CPU.
# Loading expert policy from... /Users/ikasou/Documents/Python/BerkeleyDRL_fall2021/hw1/cs285/policies/experts/Ant.pkl
# obs (1, 111) (1, 111)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# Creating offscreen glfw
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/qk/jnvrb9nx0zv7n9n25svy6d840000gn/T/ipykernel_78759/2651419942.py in <module>
#       2 print(args.logdir)
#       3 trainer = BC_Trainer(args)
# ----> 4 trainer.run_training_loop()
#
# /var/folders/qk/jnvrb9nx0zv7n9n25svy6d840000gn/T/ipykernel_78759/2558457091.py in run_training_loop(self)
#      34     def run_training_loop(self):
#      35
# ---> 36         self.rl_trainer.run_training_loop(
#      37             n_iter=self.params['n_iter'],
#      38             initial_expertdata=self.params['expert_data'],
#
# ~/Documents/Python/BerkeleyDRL_fall2021/hw1/cs285/infrastructure/rl_trainer.py in run_training_loop(self, n_iter, collect_policy, eval_policy, initial_expertdata, relabel_with_expert, start_relabel_with_expert, expert_policy)
#     104
#     105             # collect trajectories, to be used for training
# --> 106             training_returns = self.collect_training_trajectories(
#     107                 itr,
#     108                 initial_expertdata,
#
# ~/Documents/Python/BerkeleyDRL_fall2021/hw1/cs285/infrastructure/rl_trainer.py in collect_training_trajectories(self, itr, load_initial_expertdata, collect_policy, batch_size)
#     167         # HINT2: you want each of these collected rollouts to be of length self.params['ep_len']
#     168         print("\nCollecting data to be used for training...")
# --> 169         paths = utils.sample_trajectories(self.env, collect_policy, MAX_NVIDEO, MAX_VIDEO_LEN, True)
#     170         envsteps_this_batch = self.params['batch_size']
#     171         # collect more rollouts with the same policy, to be saved as videos in tensorboard
#
# ~/Documents/Python/BerkeleyDRL_fall2021/hw1/cs285/infrastructure/utils.py in sample_trajectories(env, policy, min_timesteps_per_batch, max_path_length, render, render_mode)
#      61     paths = []
#      62     while timesteps_this_batch < min_timesteps_per_batch:
# ---> 63         sample_paths = sample_trajectory(env, policy, max_path_length, render, render_mode)
#      64         paths.append(sample_paths)
#      65         timesteps_this_batch += get_pathlength(sample_paths)
#
# ~/Documents/Python/BerkeleyDRL_fall2021/hw1/cs285/infrastructure/utils.py in sample_trajectory(env, policy, max_path_length, render, render_mode)
#      28         # use the most recent ob to decide what to do
#      29         obs.append(ob)
# ---> 30         ac = policy.get_action(ob) # TODO # HINT: query the policy's get_action function
#      31         ac = ac[0]
#      32         acs.append(ac)
#
# ~/Documents/Python/BerkeleyDRL_fall2021/hw1/cs285/policies/MLP_policy.py in get_action(self, obs)
#      82
#      83         # TODO return the action that the policy prescribes
# ---> 84         raise NotImplementedError
#      85
#      86     # update/train this policy
#
# NotImplementedError:

# %%
#@markdown You can visualize your runs with tensorboard from within the notebook

# %load_ext tensorboard
# %tensorboard --logdir ~/Documents/Python/BerkeleyDRL_fall2021/hw1/data
# Out:
# Launching TensorBoard...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_33204/2513354305.py in <module>
#       2
#       3 get_ipython().run_line_magic('load_ext', 'tensorboard')
# ----> 4 get_ipython().run_line_magic('tensorboard', '--logdir ~/Documents/Python/BerkeleyDRL_fall2021/hw1/data')
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# ~/.local/lib/python3.7/site-packages/tensorboard/notebook.py in _start_magic(line)
#     113 def _start_magic(line):
#     114   """Implementation of the `%tensorboard` line magic."""
# --> 115   return start(line)
#     116
#     117
#
# ~/.local/lib/python3.7/site-packages/tensorboard/notebook.py in start(args_string)
#     148
#     149   parsed_args = shlex.split(args_string, comments=True, posix=True)
# --> 150   start_result = manager.start(parsed_args)
#     151
#     152   if isinstance(start_result, manager.StartLaunched):
#
# ~/.local/lib/python3.7/site-packages/tensorboard/manager.py in start(arguments, timeout)
#     402         ["tensorboard"] + arguments,
#     403         stdout=stdout_fd,
# --> 404         stderr=stderr_fd,
#     405     )
#     406   finally:
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     798                                 c2pread, c2pwrite,
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#     802             # Cleanup if the child failed starting.
#
# /usr/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                         if errno_num == errno.ENOENT:
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tensorboard': 'tensorboard'

# %% [markdown]
# ## Running DAgger (Problem 2)
# Modify the settings above:
# 1. check the `do_dagger` box
# 2. set `n_iters` to `10`
# and then rerun the code.
